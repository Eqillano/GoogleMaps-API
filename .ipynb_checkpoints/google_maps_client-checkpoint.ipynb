# %%
from urllib.parse import urlencode
import requests
import pprint

# %%
google_api_key = 'AIzaSyCbrDbk2Rciyeo52eMjAejXmLAa-0l3qSI'

# %% [markdown]
# ### Google Maps Client API

# %%
class GoogleMapsClient(object):
    lat = None
    lng = None
    data_type = 'json'
    location_query = None
    api_key = None
    
    def __init__(self, api_key=None, address_or_postal_code=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        if api_key == None:
            raise Exception("API key is required")
        self.api_key = api_key
        self.location_query = address_or_postal_code
        if self.location_query != None:
            self.extract_lat_lng()
    
    def extract_lat_lng(self, location=None):
        loc_query = self.location_query
        if location != None:
            loc_query = location
        endpoint = f"https://maps.googleapis.com/maps/api/geocode/{self.data_type}"
        params = {"address": loc_query, "key": self.api_key}
        url_params = urlencode(params)
        url = f"{endpoint}?{url_params}"
        r = requests.get(url)
        if r.status_code not in range(200, 299): 
            return {}
        latlng = {}
        try:
            latlng = r.json()['results'][0]['geometry']['location']
        except:
            pass
        lat,lng = latlng.get("lat"), latlng.get("lng")
        self.lat = lat
        self.lng = lng
        return lat, lng
    
    def search(self, keyword='Торговый центр', radius=5000, location=None):
        lat, lng = self.lat, self.lng
        if location != None:
            lat, lng = self.extract_lat_lng(location=location)
        endpoint = f"https://maps.googleapis.com/maps/api/place/nearbysearch/{self.data_type}"
        params = {
            "key": self.api_key,
            "location": f"{lat},{lng}",
            "radius": radius,
            "keyword": keyword
        }
        params_encoded = urlencode(params)
        places_url = f"{endpoint}?{params_encoded}"
        r = requests.get(places_url)
        # print(places_url, r.text)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def detail(self, place_id="ChIJlXOKcDC3j4ARzal-5j-p-FY", fields=["name", "rating", "formatted_phone_number", "formatted_address"]):
        detail_base_endpoint = f"https://maps.googleapis.com/maps/api/place/details/{self.data_type}"
        detail_params = {
            "place_id": f"{place_id}",
            "fields" : ",".join(fields),
            "key": self.api_key
        }
        detail_params_encoded = urlencode(detail_params)
        detail_url = f"{detail_base_endpoint}?{detail_params_encoded}"
        r = requests.get(detail_url)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

# %%
client = GoogleMapsClient(api_key=google_api_key,address_or_postal_code='603003')
print(client.lat)
print(client.lng)
# Out:
# 12.6746819
# 80.0199562

# %%
client.search('Gym',radius=5000)
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6901816, 'lng': 79.9788698},
#     'viewport': {'northeast': {'lat': 12.69152932989272,
#       'lng': 79.98025872989273},
#      'southwest': {'lat': 12.68882967010728, 'lng': 79.97755907010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'dcb72a0c647b8484cd1a9c85757bf02fcf1e4b56',
#    'name': 'Extreme Gym',
#    'permanently_closed': True,
#    'place_id': 'ChIJT8suzW78UjoRaF2Rxd1gzGE',
#    'plus_code': {'compound_code': 'MXRH+3G Gokulapuram, Tamil Nadu, India',
#     'global_code': '7J4XMXRH+3G'},
#    'rating': 3,
#    'reference': 'ChIJT8suzW78UjoRaF2Rxd1gzGE',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Gokulapuram'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6897877, 'lng': 79.9746677},
#     'viewport': {'northeast': {'lat': 12.69113752989272,
#       'lng': 79.97601882989271},
#      'southwest': {'lat': 12.68843787010728, 'lng': 79.97331917010726}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'f7779b76457c9b31b614d06d81e95262af2f68ba',
#    'name': 'Easy fit gym',
#    'permanently_closed': True,
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118239063236420521142">Pradeep Vijay</a>'],
#      'photo_reference': 'CmRaAAAAV_i2PZNJtV445MDjEgtnDdqN_EGcrvdQySiVjyOvKs2zPW4vXxxlzJShvp0I1nNMcaYBacrXj_JaJJ8h4-xe95RKeLtT4TdmXAPFVziJCLg_t2MUc_nJRSPpwN566rRDEhDXTI49vvyZ74h1iBKjIG2vGhTK9dmcR8cAozM5bc2KKWFyY1hxZA',
#      'width': 4160}],
#    'place_id': 'ChIJpRNRBmb8UjoRlTQ4QKrBR3A',
#    'plus_code': {'compound_code': 'MXQF+WV J C K Nagar, Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXQF+WV'},
#    'rating': 4.4,
#    'reference': 'ChIJpRNRBmb8UjoRlTQ4QKrBR3A',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': 'Gandhi Salai, J C K Nagar, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6833089, 'lng': 79.9832186},
#     'viewport': {'northeast': {'lat': 12.68477042989272,
#       'lng': 79.98458677989272},
#      'southwest': {'lat': 12.68207077010728, 'lng': 79.98188712010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '12af3c8b0ff9241cbd4437a0d9218901bd9c47c7',
#    'name': 'REAL VALUE FITNESS',
#    'permanently_closed': True,
#    'photos': [{'height': 1600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107789658925799289755">REAL VALUE FITNESS</a>'],
#      'photo_reference': 'CmRaAAAAv8ZBHsAsszD10n2acSIqaV6uDEjNBtXjJfTybxzcXIaOFUjGCj8rgj0xHUwQKkWUyq5YLGQ0nmuodtAZKxD701qhKTIDzGCahQo-_R1us1IneMhB4Gq7yGxsICaj6Yc1EhAi12hd6HMjzpxdzskRh91EGhT_rWepV0c4LXyHrCyh4ZGRvigdcA',
#      'width': 2400}],
#    'place_id': 'ChIJ61S2yUH8UjoRQFC6lSmNNQo',
#    'plus_code': {'compound_code': 'MXMM+87 Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXMM+87'},
#    'rating': 4.6,
#    'reference': 'ChIJ61S2yUH8UjoRQFC6lSmNNQo',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 143,
#    'vicinity': 'NO.84/1, GST ROAD, CHEZHIYAN COMPLEX,2ND FLOOR RATINAM KINARU, GREEN TRENDZ UPSTAIR, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6832627, 'lng': 79.9840897},
#     'viewport': {'northeast': {'lat': 12.68461797989272,
#       'lng': 79.98538857989271},
#      'southwest': {'lat': 12.68191832010728, 'lng': 79.98268892010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png',
#    'id': '76d6723a0bab9918f641f766ebb80f3158c33cd2',
#    'name': 'Bhai Gym',
#    'permanently_closed': True,
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108849618615257237516">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAp-aNLTfU2xTXu7uaKsDzr1YFf1013CegrI2wHAxgDkY0hcRrTjxn-r_fwMP7PD8gG6qwUT7drf9xDIEf6GUADpQd-sWsKUc9KHyNwQG3uZxCgHXuMfFJtgIV6CcD_lEDEhDxGwIfl6DtOOgwr2xu9oy_GhT9SOb5CeenzGVCeEX9HeIUIGQ5KA',
#      'width': 1836}],
#    'place_id': 'ChIJlaVYZgn9UjoR_gxqm51BEpg',
#    'plus_code': {'compound_code': 'MXMM+8J Anna Nagar, Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXMM+8J'},
#    'rating': 5,
#    'reference': 'ChIJlaVYZgn9UjoR_gxqm51BEpg',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Anna Nagar, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6815248, 'lng': 79.9905777},
#     'viewport': {'northeast': {'lat': 12.68290077989272,
#       'lng': 79.99186282989271},
#      'southwest': {'lat': 12.68020112010728, 'lng': 79.98916317010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '8560722d0349407fa697a0e353532b684c2cb482',
#    'name': 'WARRIOR ZONE GYM & FITNESS',
#    'permanently_closed': True,
#    'photos': [{'height': 810,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101849524672771937673">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAdcwOQ12nUHdolrAzbiA9r1dILl1N-l0NWnKlD4e9j7pfRQ83HlKE_trHY_kjBWyy00PooTYJsnwRfCtqb72veUrNOOjgilrNDc1m8h7H78D2vHvxRW3MEpdVzwMgdQXZEhBHbIvl15FjOXFP62ZkDyaiGhRnVQ3XwPTqtjXrlKUO5r_nw_-ppg',
#      'width': 1440}],
#    'place_id': 'ChIJqb189iz9UjoRNsESZSOfJZw',
#    'plus_code': {'compound_code': 'MXJR+J6 Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXJR+J6'},
#    'rating': 4.4,
#    'reference': 'ChIJqb189iz9UjoRNsESZSOfJZw',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': 'TKM Rd, MELAMAIYYUR, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6872092, 'lng': 79.9831217},
#     'viewport': {'northeast': {'lat': 12.68855517989272,
#       'lng': 79.98443177989272},
#      'southwest': {'lat': 12.68585552010728, 'lng': 79.98173212010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '2926e8f4bbe260362a0d804d4476a949d0a545c0',
#    'name': 'Muscle & martial fitness studio',
#    'permanently_closed': True,
#    'place_id': 'ChIJmQJNBWf9UjoR9VMZdbpI0ng',
#    'plus_code': {'compound_code': 'MXPM+V6 Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXPM+V6'},
#    'rating': 0,
#    'reference': 'ChIJmQJNBWf9UjoR9VMZdbpI0ng',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Graced Enterprises No# 106, GST Rd, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6701743, 'lng': 79.9788219},
#     'viewport': {'northeast': {'lat': 12.67159837989272,
#       'lng': 79.98017167989272},
#      'southwest': {'lat': 12.66889872010728, 'lng': 79.97747202010729}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '199ea0d21ebffc84f6127aa5e0cc6691b9fa0baa',
#    'name': "Chengalpattu Medical College Men's Gym",
#    'permanently_closed': True,
#    'place_id': 'ChIJZTzp4k78UjoRgYqmZynKvlY',
#    'plus_code': {'compound_code': 'MXCH+3G VOC Nagar, Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXCH+3G'},
#    'rating': 4,
#    'reference': 'ChIJZTzp4k78UjoRgYqmZynKvlY',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': 'VOC Nagar, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6733372, 'lng': 79.98678269999999},
#     'viewport': {'northeast': {'lat': 12.67465912989272,
#       'lng': 79.98799852989272},
#      'southwest': {'lat': 12.67195947010728, 'lng': 79.98529887010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'b3471a07ec5d4a9b730e05fd74dff6b36d0ee264',
#    'name': 'MFC FOOTBALL GROUND',
#    'permanently_closed': True,
#    'place_id': 'ChIJB25Zs0j9UjoRhaGss1G16CQ',
#    'plus_code': {'compound_code': 'MXFP+8P Kamarajar Nagar, Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXFP+8P'},
#    'rating': 0,
#    'reference': 'ChIJB25Zs0j9UjoRhaGss1G16CQ',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Kamarajar Nagar, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6811033, 'lng': 79.9802677},
#     'viewport': {'northeast': {'lat': 12.68244217989272,
#       'lng': 79.98164777989273},
#      'southwest': {'lat': 12.67974252010728, 'lng': 79.97894812010729}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '626fec398872e0c44c40e276d61a5d10fc48a542',
#    'name': 'herbalife nutritioncentre',
#    'permanently_closed': True,
#    'photos': [{'height': 1400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117270773446337569178">prabu S</a>'],
#      'photo_reference': 'CmRaAAAATa_NBHpUdJ8ITInXoThRAwF4-xM34Odv9pAFlUzLM_LW3D3D9aBv0qTQXIFb_Ns4GHqYquM69OjcPqW7eWeikQSZvK1h3iBB9RDgSIYXAbdJqHdn7KZvou3ARIPL0lLmEhAoFcPnJlNfYMdaXx_YGzBMGhQYqJteSejxfqMZeVJAmohLLal7OQ',
#      'width': 1050}],
#    'place_id': 'ChIJw9hb0EP8UjoRs2FcIy63-sI',
#    'plus_code': {'compound_code': 'MXJJ+C4 Varadharaja Nagar, Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXJJ+C4'},
#    'rating': 3.8,
#    'reference': 'ChIJw9hb0EP8UjoRs2FcIy63-sI',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Rajeswari Vedachalam St, Alagesan Nagar, Varadharaja Nagar, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6713182, 'lng': 79.98369339999999},
#     'viewport': {'northeast': {'lat': 12.67255412989272,
#       'lng': 79.98529807989271},
#      'southwest': {'lat': 12.66985447010728, 'lng': 79.98259842010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '2f01896589adb8c0b511309f8193a48eb2991097',
#    'name': 'sakthi Ram Anand Academy',
#    'permanently_closed': True,
#    'place_id': 'ChIJVQpoWEj8UjoRLhFpYSjbKZI',
#    'plus_code': {'compound_code': 'MXCM+GF Kamarajar Nagar, Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXCM+GF'},
#    'rating': 3,
#    'reference': 'ChIJVQpoWEj8UjoRLhFpYSjbKZI',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Kamarajar Nagar, Jaja'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6944025, 'lng': 79.9744125},
#     'viewport': {'northeast': {'lat': 12.69574682989272,
#       'lng': 79.97576442989272},
#      'southwest': {'lat': 12.69304717010728, 'lng': 79.97306477010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'de63e1c009880a8658387f7717a37ebc5b820f5c',
#    'name': 'LIFE STYLE Sports & Fitness Academy',
#    'permanently_closed': True,
#    'photos': [{'height': 576,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102191522288817763121">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAz7eHl59gbmerIt9_FN3Q1KqEDWXty-7jJVzgjVJpGttDFzOPa2uifD-iBMngukxzp9jasltu7CTMhaK9vZFnEcbgpnwK-Y6owhl2LidYxFWXOt-P3tYBR4jwfEx2VoVQEhB8M8ahxu1-Y1JucYrpOXVCGhQOgYQv_UkncNnrEwy2EmkMHTbPsg',
#      'width': 1152}],
#    'place_id': 'ChIJLyHkQmX8UjoRarj_lw9QMKk',
#    'plus_code': {'compound_code': 'MXVF+QQ Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXVF+QQ'},
#    'rating': 4.8,
#    'reference': 'ChIJLyHkQmX8UjoRarj_lw9QMKk',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 38,
#    'vicinity': 'No :21 , RV Super Market ,Near Old Bus Stand ,chengalpattu, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6834442, 'lng': 79.9839499},
#     'viewport': {'northeast': {'lat': 12.68479147989272,
#       'lng': 79.98532402989272},
#      'southwest': {'lat': 12.68209182010728, 'lng': 79.98262437010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'dc7d70ec601f128e31ff9e2eabec10ae1595f99c',
#    'name': 'Rehabilitation fitness center',
#    'permanently_closed': True,
#    'photos': [{'height': 5760,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101772850960875704639">A Google User</a>'],
#      'photo_reference': 'CmRaAAAANEii1A-jhTMx5HG6xhOQd0ZXodMNqU9AO1wUYoCaM1x80qYP6BOUg5bc-4uCCvU6Kquwoz0vqrIzeT4R-HG3QpkckwPACP7HNhrnrM12G1g1hpkffAoATGkBULNqklwdEhDWQk-HXAFbbGTl-grH92lKGhSh_ggLH5kc4_8FVGlkUHmaB0zDTg',
#      'width': 4320}],
#    'place_id': 'ChIJ9Zxnp5L9UjoR_gRs8ahgi6o',
#    'plus_code': {'compound_code': 'MXMM+9H Anna Nagar, Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXMM+9H'},
#    'rating': 0,
#    'reference': 'ChIJ9Zxnp5L9UjoR_gRs8ahgi6o',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Muthurajan street,Thirukazhukundram Road, Anna Nagar, Chengalpattu'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 12.6936009, 'lng': 79.97325459999999},
#     'viewport': {'northeast': {'lat': 12.69493047989272,
#       'lng': 79.97460137989272},
#      'southwest': {'lat': 12.69223082010728, 'lng': 79.97190172010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'a3c71f5803430fad9274d0f70ac632b08c26d965',
#    'name': 'Sss Tuition',
#    'permanently_closed': True,
#    'place_id': 'ChIJxRvpuOz9UjoRyVHxZy4fvYo',
#    'plus_code': {'compound_code': 'MXVF+C8 J C K Nagar, Chengalpattu, Tamil Nadu, India',
#     'global_code': '7J4XMXVF+C8'},
#    'rating': 0,
#    'reference': 'ChIJxRvpuOz9UjoRyVHxZy4fvYo',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Unnamed Road, J C K Nagar, Chengalpattu'}],
#  'status': 'OK'}

# %%
client.detail(place_id='ChIJacPkPdvVUUERXbAQgXNfuMw')
# Out:
# {'html_attributions': [],
#  'result': {'formatted_address': "площадь Революции, 9, Nizhnij Novgorod, Nizhegorodskaya oblast', Russia, 603002",
#   'formatted_phone_number': '8 (831) 277-92-22',
#   'name': 'Respublika',
#   'rating': 4.3},
#  'status': 'OK'}
